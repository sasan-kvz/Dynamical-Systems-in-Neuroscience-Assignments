    def obterUltimoElementoArray(a):
        return a[len(a)-1]

    def obterUltimoElementoTHistorico():
        return obterUltimoElementoArray(historico_t)

    def obterV(t):
        # validating the input parameter:
        if t < array_t[0]:
            # raise "t must be greater than array_t[0]"
            return 0.0  

        if t > array_t[len(array_t)-1]:
            raise "t must be less than or equal to the last element of the getLastHistoricalElement parameter"

        # setting the interpolation range:
        b = 0
        while t > array_t[b]:
            b = b + 1

        a = b - 1

        ta = array_t[a]
        va = array_v[a]
        tb = array_t[b]
        vb = array_v[b]

        # interpolating by a line:
        coefAngular = (vb - va) / (tb - ta)
        coefLinear = va - coefAngular * ta

        def reta(x): return coefAngular * x + coefLinear
        return reta(t)

    # current function (pulse)
    def I(t):
        if (t < t_inicial + 0.05) or (t > t_inicial + 2 and t < t_inicial + 2 + 0.05) or (t > t_inicial + 4 and t < t_inicial + 4 + 0.05):        
            return 0.1
        else:
            return 0.0

    # function to be integrated (replaces one of the equations from the original model)
    def integrando(t, ts):
        return np.exp(-(t - ts) / 2) * obterV(ts)

    def integralNumericaPontoFixo(t):
        t0 = 1
        tk = 2
        somatorio = 0
        while tk >= t0:
            f1 = integrando(t, tk)
            f2 = integrando(t, tk - delta_t)
            parcela = (f1 + f2) * delta_t / 2
            somatorio = somatorio + parcela
            tk = tk - delta_t
        return somatorio

    def integralNumerica(t):
        t0 = obterPrimeiroElementoTHistorico() + 0.1
        tk = t
        somatorio = 0
        while tk >= t0:
            f1 = integrando(t, tk)
            f2 = integrando(t, tk - delta_t)
            parcela = (f1 + f2) * delta_t / 2
            somatorio = somatorio + parcela
            tk = tk - delta_t
        return somatorio

    def integralNumericaOtimizada(t):
        global g_t0
        tk = t
        somatorio = 0
        while tk >= g_t0:
            f1 = integrando(t, tk)
            f2 = integrando(t, tk - delta_t)
            parcela = (f1 + f2) * delta_t / 2
            somatorio = somatorio + parcela
            tk = tk - delta_t
        return somatorio

    def integralNumericaOtimizadaMenosPontos(t, multiplicadorDeltaT):
        #global g_t0
        _delta_t = delta_t * multiplicadorDeltaT
        tk = t
        somatorio = 0
        while tk >= g_t0:
            f1 = integrando(t, tk)
            f2 = integrando(t, tk - _delta_t)
            parcela = (f1 + f2) * _delta_t / 2
            somatorio = somatorio + parcela
            tk = tk - _delta_t
        return somatorio

    def getT0(t, tmin, step):
        tk = t
        while tk >= tmin:
            v1 = obterV(tk)
            v2 = obterV(tk - step)
            dvdt = (v1 - v2) / step
            if dvdt > 0 and v1 > 0.6: 
                break
            tk = tk - step
        return tk

    def integralNumericaLimitada(t):
        delta_t2 = 0.4
        tmax = 1.4
        t0 = getT0(t, t - tmax, 0.01)
        delta_t2 = (t - t0)/2
        if delta_t2 < 0.01:
            return 0
        g_delay_t.append(t)
        g_delay.append(delta_t2)
        tk = t
        somatorio = 0
        while tk >= t0:
            f1 = integrando(t, tk)
            f2 = integrando(t, tk - delta_t2)
            parcela = (f1 + f2) * delta_t2 / 2
            somatorio = somatorio + parcela
            tk = tk - delta_t2
        return somatorio

    def integralNumericaLimitada2(t):

        if t >= 4:
            t0 = 4
        else:
            t0 = 2  

        delta_t2 = (t - t0)/50
        if delta_t2 < 0.01/50: 
            return 0
        g_delay_t.append(t)
        g_delay.append(delta_t2)
        tk = t
        somatorio = 0
        while tk >= t0:
            f1 = integrando(t, tk)
            f2 = integrando(t, tk - delta_t2)
            parcela = (f1 + f2) * delta_t2 / 2
            somatorio = somatorio + parcela
            tk = tk - delta_t2
        if somatorio <= 0.0:
            return 0
        return somatorio

    def pontual(t):
        global g_t0
        t0 = g_t0
            
        delta_t2 = (t - t0)/1

        g_delay_t.append(t)
        g_delay.append(delta_t2)

        somatorio = obterV(t) * delta_t2 / 2

        return somatorio


    def delay(t):        
        global g_t0
        t0 = g_t0

        delta_t2 = (t - t0)/2

        g_delay_t.append(t)
        g_delay.append(delta_t2)

        tk = t
        f1 = integrando(t, tk)
        f2 = integrando(t, tk - delta_t2)

        delay = (f1 +  2 * f2) * delta_t2 / 2

        if delay <= 0:
            return 0

        return delay

    def integralDelayFixo(t):
        f1 = integrando(t, t)
        f2 = integrando(t, t - delay_t)
        area = (f1 + f2) * delay_t / 2
        return area

    def integralDelayFixoMultiponto(t):
        tk = t - delay_t
        somatorio = 0
        step_t = 0.05
        while tk <= t:
            f1 = integrando(t, tk)
            f2 = integrando(t, tk - step_t)
            parcela = (f1 + f2) * step_t / 2
            somatorio = somatorio + parcela
            tk = tk + step_t
        return somatorio

    def funcaoIntegral(t):
        w = integralNumericaOtimizada(t) 
        w_array_t.append(t)
        w_array_w.append(w)
        return w

    def dvdt(t):
        s = obterV(t) * (0.1 - obterV(t))
        s_array_t.append(t)
        s_array_w.append(s)
        return 100 * s * (obterV(t) - 1.0) + 100 * I(t) - 100 * funcaoIntegral(t)

    delta_t = 0.01

    t_inicial = obterUltimoElementoTHistorico() + delta_t
    t_final = t_inicial + t_duracao

    start_time = time.time()

    t = t_inicial

    while t <= t_final:
        derivada = dvdt(t - delta_t)
        v = obterV(t - delta_t) + delta_t * derivada
        if derivada > 0 and v > 0 and v < 0.15:
            g_t0 = t
        array_t.append(t)
        array_v.append(v)
        t = t + delta_t

    x = array('d')
    y = array('d')
    xf = 3.2
    xk = obterPrimeiroElementoTHistorico()
    xk_step = 0.32
    while xk <= xf:
        x.append(xk)
        y.append(integrando(xf, xk))
        xk = xk + xk_step

    for m in range(0, len(array_v)):
        array_t[m] = array_t[m] - 2

    for n in range(0, len(w_array_t)):
        w_array_t[n] = w_array_t[n] - 2

    print_array_t = array('d')
    print_array_v = array('d')
    print_array_hist_t = array('d')
    print_array_hist_v = array('d')

    for l in range(0, len(array_v)):
        if l < idx_inicio_v:
            print_array_hist_t.append(array_t[l])
            print_array_hist_v.append(array_v[l])
        elif l == idx_inicio_v:
            print_array_t.append(array_t[l])
            print_array_v.append(array_v[l])
        else:
            print_array_t.append(array_t[l])
            print_array_v.append(array_v[l])

    if not g_zerar_historico:
        plt.plot(print_array_hist_t, print_array_hist_v, 'r-', label='historico')

    plt.plot(print_array_t, print_array_v, 'b-', label='u')
    plt.plot(w_array_t, w_array_w, 'r-', label='w')

    plt.title("Results of integro-differential equation with the sliding-window method")
    plt.legend()
    plt.xlabel('t')
    plt.ylabel('u')
    plt.show()


run(7, 0.23)


# In[ ]:
